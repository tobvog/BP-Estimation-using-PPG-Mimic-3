# %% [markdown]
# # Demo for the preprocessing of the ppg data

# %% [markdown]
# ### Imports

# %%
import numpy as np
import os
from scipy.signal import butter
from Preprocessing import Preprocessing_mimic3

# %% [markdown]
# ### Initialize paths

# %%
# Path of the first segmented data
path_main = "D:/MIMICIII_Database/segmented_data_slapnicar/"
# Target path
path_target = "D:/MIMICIII_Database/preprocessed_data_slapnicar/"
# Necessary subset of subject ids
ids = os.listdir(path_main)  
ids = ids[:50]

# %% [markdown]
# ### Function for filter coefficient

# %%
def design_filt(fs=125, lowcut=0.5, highcut=8, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    sos = butter(order, [low, high], btype='band', output="sos") 
    
    return sos

# %% [markdown]
# ### Preprocess data

# %%
sos = design_filt()

for i in range(0,len(ids)):
    
    # Load data
    print('Loading File Number: '+str(i+1))
    data = np.load(path_main+ids[i], allow_pickle=True)
    data = [data[0,1], data[1,1], data[0,2]]
    
    # Initialize preprocessing class
    preprocess = Preprocessing_mimic3(data, sos)
    
    # Replace NaN values
    print("Step 1/4: change_nan")
    preprocess.change_nan()
    
    # Scaling
    print("Step 2/4: scaling")
    preprocess.scaling()
    
    # Frequency filter
    print("Step 3/4: filtering(frequency)")
    preprocess.filt_freq()
    
    # Median filter
    print("Step 4/4: filtering(median)")
    preprocess.filt_median()
    
    # Get object of the class
    pleth, abp, fs = preprocess.get_obj()
    
    print("|------------------------------|")
    # In order to save the data, the following should not be commented
    # np.save(path_target+ids[i], [pleth, abp, fs])
# Out:
# Loading File Number: 1
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 2
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 3
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 4
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 5
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 6
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 7
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 8
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 9
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 10
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 11
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 12
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 13
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 14
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 15
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 16
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 17
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 18
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 19
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 20
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 21
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 22
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 23
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 24
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 25
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 26
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 27
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 28
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 29
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 30
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 31
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 32
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 33
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 34
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 35
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 36
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 37
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 38
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 39
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 40
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 41
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 42
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 43
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 44
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 45
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 46
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 47
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 48
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 49
# Step 1/4: change_nan
# Step 2/4: scaling
# Step 3/4: filtering(frequency)
# Step 4/4: filtering(median)
# |------------------------------|
# Loading File Number: 50
# Step 1/4: change_nan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [12], line 15
#      13 # Replace NaN values
#      14 print("Step 1/4: change_nan")
# ---> 15 preprocess.change_nan()
#      17 # Scaling
#      18 print("Step 2/4: scaling")
#
# File ~\Desktop\Study\Master BMIT\1.Semester\Programmierprojekt\Skript\Preprocessing.py:59, in Preprocessing_mimic3.change_nan(cls)
#      56 if np.isnan(data[i]) == True and np.isnan(data[i+1]) == False:
#      57     result[i] = int((result[i-1]+result[i+1])/2)
# ---> 59 elif np.isnan(data[i]) == True and np.isnan(data[i+1]) == True and np.isnan(data[i+2]) == False:
#      60     result[i] = int((result[i-1]+result[i+2])/2)
#      61     result[i+1] = int((result[i-1]+result[i+2])/2)
#
# IndexError: index 206750 is out of bounds for axis 0 with size 206750
