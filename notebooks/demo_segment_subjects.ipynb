# %% [markdown]
# # Demo for the last subject segmentation and extract peaks

# %% [markdown]
# ### Imports

# %%
import numpy as np
import os
from imports.Elgendi_peak import ElgPeakDetection
from imports.Preprocessing import Preprocessing_mimic3

# %% [markdown]
# ### Initialize paths

# %%
# Path of preprocessed data
path_data = "D:/MIMICIII_Database/preprocessed_data_slapnicar/"
# Target path
path_target = "C:/Users/vogel/Desktop/Study/Master BMIT/1.Semester/Programmierprojekt/cycled_data/"
# Necessary subset of subject ids
ids = os.listdir(path_data)
ids = ids[:100]

# %% [markdown]
# ### Extract data

# %%
stats_all = []
for i in range(0, len(ids)):
    # Loading data
    print('Loading File Number: ', i+1, " of ", len(ids))
    data = np.load(path_data+ids[i], allow_pickle=True)
    pleth = data[0]
    abp = data[1]

    # Detect peaks and correct data lengths
    print("Step 1: Peak Detection")
    peak_detect = ElgPeakDetection(data)
    idx_blocks, idx_peaks, pleth_new, abp_new = peak_detect.process()

    # Cycle Segmentation
    print("Step 2: Segment Cycles")
    preprocess = Preprocessing_mimic3([pleth_new, abp_new, data[2]], None)
    pleth_cycle, abp_cycle = preprocess.segment_cycles(idx_peaks, [30, 110])

    # Detect passing subjects
    stats, flats = preprocess.detect_flat(data=[pleth_cycle, abp_cycle], edge_lines=0.1, edge_peaks=0.05)
    stats_all.append(stats)

    # if subject passed, failed cycles need to filtered
    if stats[0]==True:
        print(ids[i], " passed")
        idx_new = []
        for idx in range(0, len(pleth_cycle)):
            if flats[0][idx]==False and flats[1][idx]==False:
                idx_new.append(idx)

        # Save passed subject without failed cycles
        pleth_cycle_new = pleth_cycle[idx_new]
        abp_cycle_new = abp_cycle[idx_new]
        idx_peaks_new = idx_peaks[idx_new]
        # np.save(target_path+ids[i], [pleth_cycle_new, abp_cycle_new, data[2], idx_peaks_new])

    else:
        print(ids[i], " failed")
    print("|--------------------------------------|")

# Saving statistical data        
# np.save(target_path+"stats.npy", np.array(stats_all))
# Out:
# Loading File Number:  1  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.984665820642978
# Peaks: 0.568422165820643
# 3000063_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  2  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.16570327552986513
# Peaks: 0.019267822736030827
# 3000393_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  3  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9988003299092749
# Peaks: 0.4565494489015521
# 3000397_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  4  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.967556080283353
# Peaks: 0.08959622195985832
# 3000435_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  5  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.19430051813471502
# Peaks: 0.08549222797927461
# 3000480_0013.npy  failed
# |--------------------------------------|
# Loading File Number:  6  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.985278852505426
# Peaks: 0.026202384322607027
# 3000484_0008.npy  failed
# |--------------------------------------|
# Loading File Number:  7  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9953232462173315
# Peaks: 0.938101788170564
# 3000701_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  8  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9186914265879903
# Peaks: 0.0021693856299895868
# 3000714_0001.npy  failed
# |--------------------------------------|
# Loading File Number:  9  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.7903725408120552
# Peaks: 0.5401423189619088
# 3000781_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  10  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.15372393247269117
# Peaks: 0.08162859980139027
# 3000860_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  11  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.47026759167492566
# Peaks: 0.03518334985133796
# 3000960_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  12  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.75
# Peaks: 0.5
# 3000983_0001.npy  failed
# |--------------------------------------|
# Loading File Number:  13  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.15581274320791985
# Peaks: 0.004045087347865684
# 3000989_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  14  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9984974572353214
# Peaks: 0.9025658807212206
# 3001202_0017.npy  failed
# |--------------------------------------|
# Loading File Number:  15  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.09607577807848444
# Peaks: 0.06359945872801083
# 3001203_0007.npy  failed
# |--------------------------------------|
# Loading File Number:  16  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.8808579221423258
# Peaks: 0.032729977684106126
# 3001262_0008.npy  failed
# |--------------------------------------|
# Loading File Number:  17  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.991152889134642
# Peaks: 0.5805916505391209
# 3001469_0013.npy  failed
# |--------------------------------------|
# Loading File Number:  18  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9883203559510567
# Peaks: 0.6746384872080089
# 3001551_0022.npy  failed
# |--------------------------------------|
# Loading File Number:  19  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.1267510548523207
# Peaks: 0.019831223628691982
# 3001554_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  20  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9978046511627907
# Peaks: 0.10415813953488372
# 3001689_0001.npy  failed
# |--------------------------------------|
# Loading File Number:  21  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.09262505055952541
# Peaks: 0.03788593771066469
# 3001912_0005.npy  passed
# |--------------------------------------|
# Loading File Number:  22  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.3286228452358401
# Peaks: 0.016215192271263498
# 3001937_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  23  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.6750396266290948
# Peaks: 0.35268800634026065
# 3001980_0015.npy  failed
# |--------------------------------------|
# Loading File Number:  24  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9987733230034218
# Peaks: 0.50868358189683
# 3002090_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  25  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.21159153633854647
# Peaks: 0.0
# 3002094_0010.npy  failed
# |--------------------------------------|
# Loading File Number:  26  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.3291287386215865
# Peaks: 0.009362808842652795
# 3002151_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  27  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.28203155059638324
# Peaks: 0.2504809542131589
# 3002229_0022.npy  failed
# |--------------------------------------|
# Loading File Number:  28  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.5867261572783046
# Peaks: 0.16424986056887897
# 3002324_0013.npy  failed
# |--------------------------------------|
# Loading File Number:  29  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9715259187150158
# Peaks: 0.3454206214001785
# 3002507_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  30  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.0990471969864835
# Peaks: 0.018612896077996897
# 3002511_0006.npy  passed
# |--------------------------------------|
# Loading File Number:  31  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9981758297441095
# Peaks: 0.47455789206992655
# 3002541_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  32  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.0965050068721775
# Peaks: 0.005546828980954251
# 3002546_0014.npy  passed
# |--------------------------------------|
# Loading File Number:  33  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9821306395138246
# Peaks: 0.41988972511772044
# 3002554_0005.npy  failed
# |--------------------------------------|
# Loading File Number:  34  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.3266729825165791
# Peaks: 0.053397640168805445
# 3002557_0009.npy  failed
# |--------------------------------------|
# Loading File Number:  35  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.13698944469940338
# Peaks: 0.005507113354749885
# 3002565_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  36  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.6846254927726675
# Peaks: 0.6557161629434954
# 3002579_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  37  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9957743710691824
# Peaks: 0.06862552410901468
# 3002634_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  38  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.6937377690802349
# Peaks: 0.6413894324853229
# 3002645_0017.npy  failed
# |--------------------------------------|
# Loading File Number:  39  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.4426753207241012
# Peaks: 0.12697124892246844
# 3002666_0008.npy  failed
# |--------------------------------------|
# Loading File Number:  40  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.33300690650448406
# Peaks: 0.012782187403360479
# 3002762_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  41  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.1215510812826249
# Peaks: 0.017897091722595078
# 3002921_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  42  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.5466893039049237
# Peaks: 0.166723259762309
# 3003005_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  43  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.2670534055924484
# Peaks: 0.04195608477724347
# 3003026_0007.npy  failed
# |--------------------------------------|
# Loading File Number:  44  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.24553510565780504
# Peaks: 0.010224948875255624
# 3003031_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  45  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9839861084314104
# Peaks: 0.32133899286127726
# 3003254_0149.npy  failed
# |--------------------------------------|
# Loading File Number:  46  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9960947034415426
# Peaks: 0.11447400536978276
# 3003344_0007.npy  failed
# |--------------------------------------|
# Loading File Number:  47  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.32623431051810037
# Peaks: 0.053563410096863176
# 3003405_0025.npy  failed
# |--------------------------------------|
# Loading File Number:  48  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.821948180155686
# Peaks: 0.0439869883963684
# 3003521_0001.npy  failed
# |--------------------------------------|
# Loading File Number:  49  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9990491283676703
# Peaks: 0.9870047543581616
# 3003618_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  50  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 1
# Peaks: 1
# 3003650_0007.npy  failed
# |--------------------------------------|
# Loading File Number:  51  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9950884086444007
# Peaks: 0.14845069451625134
# 3003801_0009.npy  failed
# |--------------------------------------|
# Loading File Number:  52  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.1062142940422059
# Peaks: 0.003964090008161362
# 3004031_0008.npy  failed
# |--------------------------------------|
# Loading File Number:  53  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.98989898989899
# Peaks: 0.9818181818181818
# 3004083_0005.npy  failed
# |--------------------------------------|
# Loading File Number:  54  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.7393645665051157
# Peaks: 0.06892837910608508
# 3004104_0008.npy  failed
# |--------------------------------------|
# Loading File Number:  55  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.16748366013071894
# Peaks: 0.09803921568627451
# 3004110_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  56  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9606263982102908
# Peaks: 0.11409395973154363
# 3004167_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  57  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9766266582438408
# Peaks: 0.31901452937460517
# 3004186_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  58  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9894967177242888
# Peaks: 0.41050328227571115
# 3004254_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  59  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9449785454347944
# Peaks: 0.009939709956004562
# 3004283_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  60  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.8511648170228377
# Peaks: 0.1134932281635024
# 3004325_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  61  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9780876494023905
# Peaks: 0.6713147410358565
# 3004751_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  62  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9897414424788025
# Peaks: 0.8654872814822568
# 3004774_0048.npy  failed
# |--------------------------------------|
# Loading File Number:  63  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9822981366459628
# Peaks: 0.02142857142857143
# 3004961_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  64  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9883830455259026
# Peaks: 0.8963893249607535
# 3005147_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  65  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.16813576166094152
# Peaks: 0.002516905394603236
# 3005163_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  66  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.06042122223500978
# Peaks: 0.004718609736448383
# 3005370_0010.npy  passed
# |--------------------------------------|
# Loading File Number:  67  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.13817809621289662
# Peaks: 0.044012282497441144
# 3005407_0005.npy  failed
# |--------------------------------------|
# Loading File Number:  68  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9981548895427118
# Peaks: 0.9846407021393307
# 3005810_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  69  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9979329691421822
# Peaks: 0.038750500938600746
# 3005819_0001.npy  failed
# |--------------------------------------|
# Loading File Number:  70  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9970477858393796
# Peaks: 0.152514385789342
# 3005937_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  71  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9901547116736991
# Peaks: 0.14158462259728083
# 3006154_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  72  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.21310004486316733
# Peaks: 0.0008972633467922835
# 3006202_0007.npy  failed
# |--------------------------------------|
# Loading File Number:  73  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.31096613855234545
# Peaks: 0.013482447965206586
# 3006457_0005.npy  failed
# |--------------------------------------|
# Loading File Number:  74  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.12429378531073447
# Peaks: 0.001521077792264233
# 3006488_0007.npy  failed
# |--------------------------------------|
# Loading File Number:  75  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9997205533044572
# Peaks: 0.13553164733827022
# 3006658_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  76  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9556962025316456
# Peaks: 0.6594936708860759
# 3006814_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  77  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9457387644671577
# Peaks: 0.11987073500676386
# 3006994_0010.npy  failed
# |--------------------------------------|
# Loading File Number:  78  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.46996644295302015
# Peaks: 0.41401006711409394
# 3007103_0011.npy  failed
# |--------------------------------------|
# Loading File Number:  79  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9977802989197455
# Peaks: 0.011197158782617274
# 3007104_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  80  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9890909090909091
# Peaks: 0.1006060606060606
# 3007155_0013.npy  failed
# |--------------------------------------|
# Loading File Number:  81  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9136212624584718
# Peaks: 0.260797342192691
# 3007218_0005.npy  failed
# |--------------------------------------|
# Loading File Number:  82  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.994270253063823
# Peaks: 0.5355721788954321
# 3007279_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  83  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9995722382632873
# Peaks: 0.9884046014941107
# 3007406_0007.npy  failed
# |--------------------------------------|
# Loading File Number:  84  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9957925061122378
# Peaks: 0.44722627598885584
# 3007459_0003.npy  failed
# |--------------------------------------|
# Loading File Number:  85  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9947191175752843
# Peaks: 0.19059007272194836
# 3007551_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  86  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.026779736665922784
# Peaks: 0.021200624860522203
# 3007576_0002.npy  passed
# |--------------------------------------|
# Loading File Number:  87  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9989626556016598
# Peaks: 0.9761410788381742
# 3007577_0019.npy  failed
# |--------------------------------------|
# Loading File Number:  88  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.768552939556657
# Peaks: 0.01480104639955941
# 3007580_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  89  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9946714680227253
# Peaks: 0.11564617574423046
# 3007680_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  90  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.8619773882692162
# Peaks: 0.03596631003869793
# 3007696_0002.npy  failed
# |--------------------------------------|
# Loading File Number:  91  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9945255474452555
# Peaks: 0.04744525547445255
# 3007735_0012.npy  failed
# |--------------------------------------|
# Loading File Number:  92  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.1284362325371789
# Peaks: 0.008562415502478594
# 3008006_0008.npy  failed
# |--------------------------------------|
# Loading File Number:  93  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.13071266792839192
# Peaks: 0.025162111011138345
# 3008164_0001.npy  failed
# |--------------------------------------|
# Loading File Number:  94  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9792592592592593
# Peaks: 0.19777777777777777
# 3008169_0016.npy  failed
# |--------------------------------------|
# Loading File Number:  95  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.9991462113127001
# Peaks: 0.632017075773746
# 3008213_0042.npy  failed
# |--------------------------------------|
# Loading File Number:  96  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.998658224663508
# Peaks: 0.5000628957188981
# 3008408_0006.npy  failed
# |--------------------------------------|
# Loading File Number:  97  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.12650779641070903
# Peaks: 0.0016181229773462784
# 3008477_0005.npy  failed
# |--------------------------------------|
# Loading File Number:  98  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.09409434082838077
# Peaks: 0.006363030518810652
# 3008634_0001.npy  passed
# |--------------------------------------|
# Loading File Number:  99  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.3136591669200365
# Peaks: 0.01127495692713084
# 3008771_0004.npy  failed
# |--------------------------------------|
# Loading File Number:  100  of  100
# Step 1: Peak Detection
# Step 2: Segment Cycles
# Lines: 0.2204215171574222
# Peaks: 0.04222780187171878
# 3008826_0003.npy  failed
# |--------------------------------------|
