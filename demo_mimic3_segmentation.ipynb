# %% [markdown]
# ### Demo of first segmentation of Mimic3

# %% [markdown]
# ### Imports

# %%
import numpy as np
from Datasorting_mimic3 import Datasorting_mimic3

# %% [markdown]
# ### Initialize paths

# %%
# Path of the Raw data
path_main = "D:/MIMICIII_Database/mimic3wdb-1.0.physionet.org/"
# Target path
# path_target = "D:/MIMICIII_Database/segmented_data_slapnicar/"
path_target = "D:/MIMICIII_Database/Test/"

# %% [markdown]
# ### Sort function

# %%
def first_loop(temp,i,j,add,path_o):
    data_test = []
    for k in range(1,10):
        add2 = "_000"
        path_name = str(temp)+str(add)+str(add2)+str(k)
        if sorting_.check_existence(path_name+".hea") == True:
            if sorting_.check_data_size(path_name+".dat") == True and sorting_.check_pleth_abp(path_name) == True:
                if sorting_.check_time_length(path_name) >= 10:
                    print(path_name+" passed")
                    temp = sorting_.extract_data(path_name)
                    data_test.append(temp)
                    np.save(path_o+str(add)+str(add2)+str(k), temp)
        else:
            print("break")
            break
    
    for k in range(10,100):
        add2 = "_00"
        path_name = str(temp)+str(add)+str(add2)+str(k)
        print(path_name)
        if sorting_.check_existence(path_name+".hea") == True:
            if sorting_.check_data_size(path_name+".dat") == True and sorting_.check_pleth_abp(path_name) == True:
                if sorting_.check_time_length(path_name) >= 10:
                    print(path_name+" passed")
                    temp = sorting_.extract_data(path_name)
                    data_test.append(temp)
                    np.save(path_o+str(add)+str(add2)+str(k), temp)                                        
        else:
            print("break")
            break
                
    for k in range(100,1000):
        add2 = "_0"
        path_name = str(temp)+str(add)+str(add2)+str(k)
        if sorting_.check_existence(path_name+".hea") == True:
            if sorting_.check_data_size(path_name+".dat") == True and sorting_.check_pleth_abp(path_name) == True:  
                if sorting_.check_time_length(path_name) >= 10:
                    print(path_name)
                    temp = sorting_.extract_data(path_name)
                    data_test.append(temp)
                    np.save(path_o+str(add)+str(add2)+str(k), temp)
        else:
            print("break")
            break  
               
    for k in range(1000,10000):
        add2 = "_"
        path_name = str(temp)+str(add)+str(add2)+str(k)
        if sorting_.check_existence(path_name+".hea") == True:
            if sorting_.check_data_size(path_name+".dat") == True and sorting_.check_pleth_abp(path_name) == True: 
                if sorting_.check_time_length(path_name) >= 10:
                    print(path_name+" passed")
                    temp = sorting_.extract_data(path_name)
                    data_test.append(temp)
                    np.save(path_o+str(add)+str(add2)+str(k), temp)
        else:
            print("break")
            break

# %% [markdown]
# ### Segment data

# %%
# Initialize class
sorting_ = Datasorting_mimic3()

for i in range(30,40):

    for j in range(1,10):
        add = str(i)+"0000"+str(j)
        path_name = str(i)+"/"+str(i)+"/"+add+"/"
        if sorting_.check_existence(path_name) == True:
            first_loop(path_name,i,j,add,path_main)
                        
    for j in range(10,100):
        add = str(i)+"000"+str(j)
        path_name = str(i)+"/"+str(i)+"/"+add+"/"
        if sorting_.check_existence(path_name) == True:
            first_loop(path_name,i,j,add,path_main)
             
    for j in range(100,1000):
        add = str(i)+"00"+str(j)
        path_name = str(i)+"/"+str(i)+"/"+add+"/"
        if sorting_.check_existence(path_name) == True:
            first_loop(path_name,i,j,add,path_main)  
            
    for j in range(1000,10000):
        add = str(i)+"0"+str(j)
        path_name = str(i)+"/"+str(i)+"/"+add+"/"
        if sorting_.check_existence(path_name) == True:
            first_loop(path_name,i,j,add,path_main)     
            
    for j in range(10000,100000):
        add = str(i)+str(j)
        path_name = str(i)+"/"+str(i)+"/"+add+"/"
        if sorting_.check_existence(path_name) == True:
            first_loop(path_name,i,j,add,path_main)
                        
    if i == 30:
        path_name_old = str(i)+"/"+str(i)+"/"+add+"/"
        path_name_new = str(i)+"/"+add+"/"
        
        for j in range(1,10):
            add = str(i)+"0000"+str(j)
            path_name_old = str(i)+"/"+str(i)+"/"+add+"/"
            path_name_new = str(i)+"/"+add+"/"
            if sorting_.check_existence(path_name_new) == True and sorting_.check_existence(path_name_old) == False:
                first_loop(path_name_new,i,j,add,path_main)  
                           
        for j in range(10,100):
            add = str(i)+"000"+str(j)
            path_name_old = str(i)+"/"+str(i)+"/"+add+"/"
            path_name_new = str(i)+"/"+add+"/"
            if sorting_.check_existence(path_name_new) == True and sorting_.check_existence(path_name_old) == False:
                first_loop(path_name_new,i,j,add,path_main)   
                
        for j in range(100,1000):
            add = str(i)+"00"+str(j)
            path_name_old = str(i)+"/"+str(i)+"/"+add+"/"
            path_name_new = str(i)+"/"+add+"/"
            if sorting_.check_existence(path_name_new) == True and sorting_.check_existence(path_name_old) == False:
                first_loop(path_name_new,i,j,add,path_main)  
                
        for j in range(1000,10000):
            add = str(i)+"0"+str(j)
            path_name_old = str(i)+"/"+str(i)+"/"+add+"/"
            path_name_new = str(i)+"/"+add+"/"
            if sorting_.check_existence(path_name_new) == True and sorting_.check_existence(path_name_old) == False:
                first_loop(path_name_new,i,j,add,path_main)    
                
        for j in range(10000,100000):
            add = str(i)+str(j)
            path_name_old = str(i)+"/"+str(i)+"/"+add+"/"
            path_name_new = str(i)+"/"+add+"/"
            if sorting_.check_existence(path_name_new) == True and sorting_.check_existence(path_name_old) == False:
                first_loop(path_name_new,i,j,add,path_main)
# Out:
# 30/30/3000003/3000003_0010
# 30/30/3000003/3000003_0011
# 30/30/3000003/3000003_0012
# 30/30/3000003/3000003_0013
# 30/30/3000003/3000003_0014
# 30/30/3000003/3000003_0015
# 30/30/3000003/3000003_0016
# 30/30/3000003/3000003_0017
# 30/30/3000003/3000003_0018
# break
# break
# break
# break
# 30/30/3000031/3000031_0010
# break
# break
# break
# break
# 30/30/3000051/3000051_0010
# break
# break
# break
# 30/30/3000060/3000060_0010
# 30/30/3000060/3000060_0011
# 30/30/3000060/3000060_0012
# 30/30/3000060/3000060_0013
# 30/30/3000060/3000060_0014
# 30/30/3000060/3000060_0015
# 30/30/3000060/3000060_0016
# 30/30/3000060/3000060_0017
# 30/30/3000060/3000060_0018
# 30/30/3000060/3000060_0019
# 30/30/3000060/3000060_0020
# 30/30/3000060/3000060_0021
# break
# break
# break
# 30/30/3000063/3000063_0006 passed
# break
# [['3000063_0006pleth'
# 30/30/3000358/3000358_0063
# 30/30/3000358/3000358_0064
# 30/30/3000358/3000358_0065
# 30/30/3000358/3000358_0066
# 30/30/3000358/3000358_0067
# 30/30/3000358/3000358_0068
# 30/30/3000358/3000358_0069
# 30/30/3000358/3000358_0070
# break
# break
# break
# break
# 30/30/3000386/3000386_0010
# break
# break
# break
# 30/30/3000393/3000393_0002 passed
# break
# [['3000393_0002pleth'
#   array([1.28445748, 1.26588465, 1.24828935, ..., 2.12903226, 2.08602151,
#          2.04496579])
#   125]
#  ['3000393_0002abp'
#   array([73.41268872, 72.97309178, 72.63118305, ..., 84.93989733,
#          84.5491445 , 84.25607987])                               125]]3000393_0010
# break
# break
# break
# 30/30/3000397/3000397_0003 passed
# break
# [['3000397_0003pleth'
#   array([0.27058824, 0.27058824, 0.2745098 , ..., 0.22352941, 0.22352941,
#          0.21960784])
#   125]
#  ['3000397_0003abp'
#   array([  0.        ,   0.        ,   0.        , ..., 119.999625  ,
#          112.49964844, 105.93716895])                                 125]]3000397_0010
# break
# break
# break
# break
# 30/30/3000428/3000428_0010
# break
# break
# break
# 30/30/3000435/3000435_0002 passed
# break
# [['3000435_0002pleth'
#   array([0.58431373, 0.58039216, 0.58039216, ..., 0.65490196, 0.65882353,
#          0.65882353])
#   125]
#  ['3000435_0002abp'
#   array([ 9.375  , 20.3125 , 30.46875, ...,  4.6875 ,  6.25   ,  5.46875])
#   125]]3000435_0010
# break
# break
# break
# break
# 30/30/3000458/3000458_0010
# break
# break
# break
# 30/30/3000480/3000480_0010
# 30/30/3000480/3000480_0011
# 30/30/3000480/3000480_0012
# 30/30/3000480/3000480_0013
# 30/30/3000480/3000480_0013 passed
# [['3000480_0013pleth'
#   array([1.89345064, 1.92375367, 1.95796676, ..., 2.73900293, 2.73802542,
#          2.71358749])
#   125]
#  ['3000480_0013abp'
#   array([85.67255889, 85.96562352, 86.35637635, ..., 76.24564677,
#          76.05027035, 75.80604983])                               125]]3000480_0014
# break
# break
# break
# 30/30/3000484/3000484_0008 passed
# break
# [['3000484_0008pleth'
#   array([0.41960784, 0.41568627, 0.41176471, ..., 0.48235294, 0.47843137,
#          0.4745098 ])
#   125]
#  ['3000484_0008abp' array([nan, nan, nan, ..., nan, nan, nan]) 125]]3000484_0010
# break
# break
# break
# break
# 30/30/3000497/3000497_0010
# break
# break
# break
# break
# 30/30/3000531/3000531_0010
# break
# break
# break
# 30/30/3000544/3000544_0010
# 30/30/3000544/3000544_0011
# 30/30/3000544/3000544_0012
# 30/30/3000544/3000544_0013
# 30/30/3000544/3000544_0014
# 30/30/3000544/3000544_0015
# 30/30/3000544/3000544_0016
# 30/30/3000544/3000544_0017
# 30/30/3000544/3000544_0018
# 30/30/3000544/3000544_0019
# 30/30/3000544/3000544_0020
# 30/30/3000544/3000544_0021
# 30/30/3000544/3000544_0022
# 30/30/3000544/3000544_0023
# 30/30/3000544/3000544_0024
# 30/30/3000544/3000544_0025
# break
# break
# break
# 30/30/3000577/3000577_0010
#          1.514174  ])
#   125]
#  ['3000860_0004abp'
#   array([185.02146698, 185.02146698, 185.02146698, ...,  65.74416435,
#           65.40225562,  65.109191  ])                                 125]]3000860_0010
# break
# break
# break
# break
# 30/30/3000866/3000866_0010
# break
# break
# break
# break
# 30/30/3000878/3000878_0010
# break
# break
# break
# break
# 30/30/3000879/3000879_0010
# break
# break
# break
# 30/30/3000885/3000885_0010
# 30/30/3000885/3000885_0011
# 30/30/3000885/3000885_0012
# 30/30/3000885/3000885_0013
# 30/30/3000885/3000885_0014
# 30/30/3000885/3000885_0015
# 30/30/3000885/3000885_0016
# 30/30/3000885/3000885_0017
# 30/30/3000885/3000885_0018
# 30/30/3000885/3000885_0019
# 30/30/3000885/3000885_0020
# 30/30/3000885/3000885_0021
# 30/30/3000885/3000885_0022
# 30/30/3000885/3000885_0023
# 30/30/3000885/3000885_0024
# break
# break
# break
# break
# 30/30/3000912/3000912_0010
# break
# break
# break
# 30/30/3000960/3000960_0002 passed
# break
# [['3000960_0002pleth'
#   array([0.50588235, 0.49411765, 0.48235294, ..., 0.61568627, 0.62745098,
#          0.63529412])
#   125]
#  ['3000960_0002abp'
#   array([        nan,         nan,         nan, ..., 88.28125   ,
#          88.28125   , 88.02083333])                               125]]3000960_0010
# break
# break
# break
# 30/30/3000983/3000983_0001 passed
# break
# [['3000983_0001pleth'
#   array([       nan,        nan,        nan, ..., 2.00195503, 2.00195503,
#          2.00195503])
#   125]
#  ['3000983_0001abp' array([nan, nan, nan, ...,  0.,  0.,  0.]) 125]]3000983_0010
# break
# break
# break
# 30/30/3000989/3000989_0002 passed
# break
# [['3000989_0002pleth'
#   array([       nan,        nan,        nan, ..., 2.40273705, 2.32942326,
#          2.25904203])
#   125]
#  ['3000989_0002abp'
#   array([185.02146698, 185.02146698, 185.02146698, ...,  82.49769212,
#           82.05809518,  81.61849824])                                 125]]3000989_0010
# break
# break
# break
# break
# 30/30/3000995/3000995_0010
# break
# break
# break
# 30/30/3001002/3001002_0010
# 30/30/3001002/3001002_0011
# 30/30/3001002/3001002_0012
# 30/30/3001002/3001002_0013
# 30/30/3001002/3001002_0014
# 30/30/3001002/3001002_0015
# 30/30/3001002/3001002_0016
# 30/30/3001002/3001002_0017
# 30/30/3001002/3001002_0018
# 30/30/3001002/3001002_0019
# 30/30/3001002/3001002_0020
# 30/30/3001002/3001002_0021
# 30/30/3001002/3001002_0022
# 30/30/3001002/3001002_0023
# 30/30/3001002/3001002_0024
# 30/30/3001002/3001002_0025
# 30/30/3001002/3001002_0026
# 30/30/3001002/3001002_0027
# 30/30/3001002/3001002_0028
# 30/30/3001002/3001002_0029
# 30/30/3001002/3001002_0030
# 30/30/3001002/3001002_0031
# 30/30/3001002/3001002_0032
# 30/30/3001002/3001002_0033
# 30/30/3001002/3001002_0034
# 30/30/3001002/3001002_0035
# 30/30/3001002/3001002_0036
# 30/30/3001002/3001002_0037
# 30/30/3001002/3001002_0038
# 30/30/3001002/3001002_0039
# 30/30/3001002/3001002_0040
# 30/30/3001002/3001002_0041
# 30/30/3001002/3001002_0042
# 30/30/3001002/3001002_0043
# 30/30/3001002/3001002_0044
# 30/30/3001002/3001002_0045
# 30/30/3001002/3001002_0046
# 30/30/3001002/3001002_0047
# 30/30/3001002/3001002_0048
# 30/30/3001002/3001002_0049
# 30/30/3001002/3001002_0050
# 30/30/3001002/3001002_0051
# 30/30/3001002/3001002_0052
# 30/30/3001002/3001002_0053
# 30/30/3001002/3001002_0054
# 30/30/3001002/3001002_0055
# 30/30/3001002/3001002_0056
# 30/30/3001002/3001002_0057
# 30/30/3001002/3001002_0058
# 30/30/3001002/3001002_0059
# 30/30/3001002/3001002_0060
# 30/30/3001002/3001002_0061
# break
# break
# break
# break
# 30/30/3001049/3001049_0010
# break
# break
# break
# break
# 30/30/3001055/3001055_0010
# break
# break
# break
# break
# 30/30/3001081/3001081_0010
# break
# break
# break
# break
# 30/30/3001091/3001091_0010
# break
# break
# break
# 30/30/3001099/3001099_0010
# 30/30/3001099/3001099_0011
# 30/30/3001099/3001099_0012
# 30/30/3001099/3001099_0013
# 30/30/3001099/3001099_0014
# 30/30/3001099/3001099_0015
# 30/30/3001099/3001099_0016
# 30/30/3001099/3001099_0017
# 30/30/3001099/3001099_0018
# 30/30/3001099/3001099_0019
# 30/30/3001099/3001099_0020
# 30/30/3001099/3001099_0021
# 30/30/3001099/3001099_0022
# 30/30/3001099/3001099_0023
# 30/30/3001099/3001099_0024
# 30/30/3001099/3001099_0025
# 30/30/3001099/3001099_0026
# 30/30/3001099/3001099_0027
# 30/30/3001099/3001099_0028
# 30/30/3001099/3001099_0029
# 30/30/3001099/3001099_0030
# 30/30/3001099/3001099_0031
# 30/30/3001099/3001099_0032
# 30/30/3001099/3001099_0033
# 30/30/3001099/3001099_0034
# 30/30/3001099/3001099_0035
# 30/30/3001099/3001099_0036
# 30/30/3001099/3001099_0037
# 30/30/3001099/3001099_0038
# 30/30/3001099/3001099_0039
# 30/30/3001099/3001099_0040
# break
# break
# break
# 30/30/3001107/3001107_0010
# 30/30/3001107/3001107_0011
# 30/30/3001107/3001107_0012
# 30/30/3001107/3001107_0013
# 30/30/3001107/3001107_0014
# 30/30/3001107/3001107_0015
# 30/30/3001107/3001107_0016
# 30/30/3001107/3001107_0017
# 30/30/3001107/3001107_0018
# 30/30/3001107/3001107_0019
# 30/30/3001107/3001107_0020
# 30/30/3001107/3001107_0021
# 30/30/3001107/3001107_0022
# break
# break
# break
# break
# 30/30/3001116/3001116_0010
# break
# break
# break
# break
# 30/30/3001133/3001133_0010
# break
# break
# break
# 30/30/3001158/3001158_0010
# 30/30/3001158/3001158_0011
# 30/30/3001158/3001158_0012
# 30/30/3001158/3001158_0013
# 30/30/3001158/3001158_0014
# 30/30/3001158/3001158_0015
# 30/30/3001158/3001158_0016
# 30/30/3001158/3001158_0017
# 30/30/3001158/3001158_0018
# 30/30/3001158/3001158_0019
# break
# break
# break
# break
# 30/30/3001175/3001175_0010
# break
# break
# break
# break
# 30/30/3001181/3001181_0010
# break
# break
# break
# break
# 30/30/3001200/3001200_0010
# break
# break
# break
# 30/30/3001202/3001202_0010
# 30/30/3001202/3001202_0011
# 30/30/3001202/3001202_0012
# 30/30/3001202/3001202_0013
# 30/30/3001202/3001202_0014
# 30/30/3001202/3001202_0015
# 30/30/3001202/3001202_0016
# 30/30/3001202/3001202_0017
# 30/30/3001202/3001202_0017 passed
# [['3001202_0017pleth'
#   array([0.48627451, 0.53333333, 0.57647059, ..., 0.33333333, 0.32941176,
#          0.32941176])
#   125]
#  ['3001202_0017abp'
#   array([     nan,      nan,      nan, ..., 98.4375 , 96.875  , 96.09375])
#   125]]3001202_0018
# break
# break
# break
# 30/30/3001203/3001203_0007 passed
# break
# [['3001203_0007pleth'
#   array([1.54349951, 1.52981427, 1.51808407, ..., 1.53274682, 1.52101662,
#          1.50928641])
#   125]
#  ['3001203_0007abp'
#   array([ 86.9425056 ,  86.60059687,  86.69828508, ..., 119.22845853,
#          118.69117338, 117.81197951])                                 125]]3001203_0010
# break
# break
# break
# 30/30/3001220/3001220_0010
# 30/30/3001220/3001220_0011
# 30/30/3001220/3001220_0012
# 30/30/3001220/3001220_0013
# 30/30/3001220/3001220_0014
# 30/30/3001220/3001220_0015
# 30/30/3001220/3001220_0016
# 30/30/3001220/3001220_0017
# 30/30/3001220/3001220_0018
# 30/30/3001220/3001220_0019
# 30/30/3001220/3001220_0020
# 30/30/3001220/3001220_0021
# 30/30/3001220/3001220_0022
# 30/30/3001220/3001220_0023
# 30/30/3001220/3001220_0024
# 30/30/3001220/3001220_0025
# 30/30/3001220/3001220_0026
# 30/30/3001220/3001220_0027
# 30/30/3001220/3001220_0028
# 30/30/3001220/3001220_0029
# 30/30/3001220/3001220_0030
# break
# break
# break
# break
# 30/30/3001221/3001221_0010
# break
# break
# break
# 30/30/3001262/3001262_0008 passed
# break
# [['3001262_0008pleth'
#   array([0.30588235, 0.30980392, 0.31372549, ..., 0.49803922, 0.46666667,
#          0.43529412])
#   125]
#  ['3001262_0008abp'
#   array([109.37488607, 115.20821332, 119.94779172, ...,  65.98951459,
#           65.62493164,  65.26034869])                                 125]]3001262_0010
# break
# break
# break
# break
# 30/30/3001281/3001281_0010
# break
# break
# break
# break
# 30/30/3001302/3001302_0010
# break
# break
# break
# 30/30/3001360/3001360_0010
# break
# break
# break
# break
# 30/30/3001378/3001378_0010
# break
# break
# break
# break
# 30/30/3001414/3001414_0010
# break
# break
# break
# 30/30/3001434/3001434_0010
# 30/30/3001434/3001434_0011
# 30/30/3001434/3001434_0012
# 30/30/3001434/3001434_0013
# break
# break
# break
# break
# 30/30/3001439/3001439_0010
# break
# break
# break
# break
# 30/30/3001445/3001445_0010
# break
# break
# break
# 30/30/3001469/3001469_0010
# 30/30/3001469/3001469_0011
# 30/30/3001469/3001469_0012
# 30/30/3001469/3001469_0013
# 30/30/3001469/3001469_0013 passed
# [['3001469_0013pleth'
#   array([0.53333333, 0.52941176, 0.5254902 , ..., 0.4       , 0.39607843,
#          0.39607843])
#   125]
#  ['3001469_0013abp'
#   array([      nan,       nan,       nan, ..., 139.84375, 141.40625,
#          141.40625])                                                 125]]3001469_0014
# break
# break
# break
# break
# 30/30/3001489/3001489_0010
# break
# break
# break
# 30/30/3001512/3001512_0010
# 30/30/3001512/3001512_0011
# 30/30/3001512/3001512_0012
# 30/30/3001512/3001512_0013
# 30/30/3001512/3001512_0014
# 30/30/3001512/3001512_0015
# 30/30/3001512/3001512_0016
# 30/30/3001512/3001512_0017
# 30/30/3001512/3001512_0018
# break
# break
# break
# 30/30/3001551/3001551_0010
# 30/30/3001551/3001551_0011
# 30/30/3001551/3001551_0012
# 30/30/3001551/3001551_0013
# 30/30/3001551/3001551_0014
# 30/30/3001551/3001551_0015
# 30/30/3001551/3001551_0016
# 30/30/3001551/3001551_0017
# 30/30/3001551/3001551_0018
# 30/30/3001551/3001551_0019
# 30/30/3001551/3001551_0020
# 30/30/3001551/3001551_0021
# 30/30/3001551/3001551_0022
# 30/30/3001551/3001551_0022 passed
# [['3001551_0022pleth'
#   array([2.72043011, 2.67057674, 2.61192571, ..., 1.62561095, 1.61681329,
#          1.60508309])
#   125]
#  ['3001551_0022abp'
#   array([        nan,         nan,         nan, ..., -1.70954365,
#          -1.31879082, -0.87919388])                               125]]3001551_0023
# break
# break
# break
# 30/30/3001554/3001554_0004 passed
# break
# [['3001554_0004pleth'
#   array([2.285435  , 2.28347996, 2.28250244, ..., 1.78494624, 1.76832845,
#          1.75366569])
#   125]
#  ['3001554_0004abp'
#   array([113.2206337 , 112.48797214, 111.60877826, ...,  94.12258893,
#           99.30006399, 104.67291546])                                 125]]3001554_0010
# break
# break
# break
# 30/30/3001555/3001555_0010
# 30/30/3001555/3001555_0011
# 30/30/3001555/3001555_0012
# 30/30/3001555/3001555_0013
# 30/30/3001555/3001555_0014
# 30/30/3001555/3001555_0015
# 30/30/3001555/3001555_0016
# 30/30/3001555/3001555_0017
# 30/30/3001555/3001555_0018
# 30/30/3001555/3001555_0019
# 30/30/3001555/3001555_0020
# 30/30/3001555/3001555_0021
# 30/30/3001555/3001555_0022
# 30/30/3001555/3001555_0023
# 30/30/3001555/3001555_0024
# 30/30/3001555/3001555_0025
# 30/30/3001555/3001555_0026
# 30/30/3001555/3001555_0027
# 30/30/3001555/3001555_0028
# 30/30/3001555/3001555_0029
# 30/30/3001555/3001555_0030
# 30/30/3001555/3001555_0031
# 30/30/3001555/3001555_0032
# 30/30/3001555/3001555_0033
# 30/30/3001555/3001555_0034
# 30/30/3001555/3001555_0035
# 30/30/3001555/3001555_0036
# 30/30/3001555/3001555_0037
# 30/30/3001555/3001555_0038
# 30/30/3001555/3001555_0039
# 30/30/3001555/3001555_0040
# 30/30/3001555/3001555_0041
# 30/30/3001555/3001555_0042
# 30/30/3001555/3001555_0043
# 30/30/3001555/3001555_0044
# 30/30/3001555/3001555_0045
# 30/30/3001555/3001555_0046
# 30/30/3001555/3001555_0047
# 30/30/3001555/3001555_0048
# 30/30/3001555/3001555_0049
# 30/30/3001555/3001555_0050
# 30/30/3001555/3001555_0051
# 30/30/3001555/3001555_0052
# 30/30/3001555/3001555_0053
# 30/30/3001555/3001555_0054
# 30/30/3001555/3001555_0055
# 30/30/3001555/3001555_0056
# 30/30/3001555/3001555_0057
# 30/30/3001555/3001555_0058
# 30/30/3001555/3001555_0059
# 30/30/3001555/3001555_0060
# 30/30/3001555/3001555_0061
# 30/30/3001555/3001555_0062
# 30/30/3001555/3001555_0063
# 30/30/3001555/3001555_0064
# 30/30/3001555/3001555_0065
# 30/30/3001555/3001555_0066
# 30/30/3001555/3001555_0067
# 30/30/3001555/3001555_0068
# 30/30/3001555/3001555_0069
# 30/30/3001555/3001555_0070
# 30/30/3001555/3001555_0071
# 30/30/3001555/3001555_0072
# 30/30/3001555/3001555_0073
# 30/30/3001555/3001555_0074
# 30/30/3001555/3001555_0075
# 30/30/3001555/3001555_0076
# 30/30/3001555/3001555_0077
# 30/30/3001555/3001555_0078
# 30/30/3001555/3001555_0079
# 30/30/3001555/3001555_0080
# 30/30/3001555/3001555_0081
# 30/30/3001555/3001555_0082
# 30/30/3001555/3001555_0083
# 30/30/3001555/3001555_0084
# 30/30/3001555/3001555_0085
# 30/30/3001555/3001555_0086
# 30/30/3001555/3001555_0087
# 30/30/3001555/3001555_0088
# 30/30/3001555/3001555_0089
# 30/30/3001555/3001555_0090
# 30/30/3001555/3001555_0091
# 30/30/3001555/3001555_0092
# 30/30/3001555/3001555_0093
# 30/30/3001555/3001555_0094
# 30/30/3001555/3001555_0095
# 30/30/3001555/3001555_0096
# 30/30/3001555/3001555_0097
# 30/30/3001555/3001555_0098
# 30/30/3001555/3001555_0099
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [19], line 28
#      26     path_name = str(i)+"/"+str(i)+"/"+add+"/"
#      27     if sorting_.check_existence(path_name) == True:
# ---> 28         first_loop(path_name,i,j,add,path_main)
#      30 for j in range(10000,100000):
#      31     add = str(i)+str(j)
#
# Cell In [17], line 36, in first_loop(temp, i, j, add, path_o)
#      34 path_name = str(temp)+str(add)+str(add2)+str(k)
#      35 if sorting_.check_existence(path_name+".hea") == True:
# ---> 36     if sorting_.check_data_size(path_name+".dat") == True and sorting_.check_pleth_abp(path_name) == True:
#      37         if sorting_.check_time_length(path_name) >= 10:
#      38             print(path_name)
#
# File ~\Desktop\Study\Master BMIT\1.Semester\Programmierprojekt\Skript\Datasorting_mimic3.py:30, in Datasorting_mimic3.check_data_size(self, path2, min_b)
#      23 def check_data_size(self, path2, min_b=17):
#      24     ##
#      25     # @brief            This method checks the minimum number of bytes.
#    (...)
#      28     # @return result    Bool value if data is big enough.
#      29     ##
# ---> 30     size = round(os.path.getsize(self.path1+path2)/1024) # Datasize in kB
#      31     if size > min_b:
#      32         result = True
#
# File ~\anaconda3\lib\genericpath.py:50, in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#
# KeyboardInterrupt:
